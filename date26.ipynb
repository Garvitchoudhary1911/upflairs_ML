# %%
import cv2
import skimage as ski
import matplotlib.pyplot as plit

# %%
img=cv2.imread('robot.png')
cv2.imshow('',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.reshape
# Out:
# <function ndarray.reshape>

# %%
img.shape
# Out:
# (416, 416, 3)

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
img1= plt.imread('robots.jpg')
plt.imshow(img1)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
vid=cv2.VideoCapture(0)

# %%
type(vid)
# Out:
# cv2.VideoCapture

# %%
vid.isOpened()
# Out:
# True

# %%
k=vid.read()

# %%
type(k),len(k)
# Out:
# (tuple, 2)

# %%
k
# Out:
# (True,
#  array([[[183, 175, 221],
#          [181, 172, 230],
#          [179, 170, 237],
#          ...,
#          [171, 167, 202],
#          [175, 168, 198],
#          [176, 169, 199]],
#
#         [[181, 174, 223],
#          [179, 174, 223],
#          [178, 176, 224],
#          ...,
#          [171, 167, 202],
#          [176, 169, 199],
#          [176, 169, 199]],
#
#         [[181, 174, 225],
#          [178, 173, 224],
#          [179, 177, 227],
#          ...,
#          [173, 167, 201],
#          [178, 169, 197],
#          [178, 169, 197]],
#
#         ...,
#
#         [[ 63,  56,  48],
#          [ 59,  56,  48],
#          [ 51,  53,  46],
#          ...,
#          [ 56,  55,  30],
#          [ 56,  55,  30],
#          [ 56,  55,  30]],
#
#         [[ 74,  58,  39],
#          [ 63,  56,  43],
#          [ 51,  53,  46],
#          ...,
#          [ 57,  56,  27],
#          [ 59,  57,  25],
#          [ 59,  57,  25]],
#
#         [[ 79,  56,  37],
#          [ 65,  54,  42],
#          [ 51,  53,  46],
#          ...,
#          [ 57,  57,  26],
#          [ 56,  57,  23],
#          [ 56,  58,  23]]], dtype=uint8))

# %%
flag,img=vid.read()

# %%
if flag:
    plt.imshow(img[:,:,::-1])

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
import numpy as np
from time import sleep
fd=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_smile.xml')
vid=cv2.VideoCapture(0)
while True:
    flag,img =vid.read()
    if flag:
        img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        faces= fd.detectMultiScale(img_gray,
            scaleFactor=1.1,
            minNeighbors=5,
            minSize=(50,50)                               
       )
        np.random.seed(50)
        colors=[np.random.randint(0,255,3).tolist()
                        for i in faces ]
        i=0
        for x,y,w,h in faces:
            face=img_
            cv2.rectangle(
                img,pt1=(x,y),pt2=(x+w,y+h),color=colors[i],
                thickness=8

            )
            i=i+1

        cv2.imwrite('myself.png',img)
        cv2.imshow('Preview',img)
        key=cv2.waitKey(1)
        if key==ord('q'):
            break
    else:
            print('no frames')
            break
            
           

    sleep(0.1)
vid.release()
cv2.waitKey(1)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 19
#      17 i=0
#      18 for x,y,w,h in faces:
# ---> 19     face=img_
#      20     cv2.rectangle(
#      21         img,pt1=(x,y),pt2=(x+w,y+h),color=colors[i],
#      22         thickness=8
#      23
#      24     )
#      25     i=i+1
#
# NameError: name 'img_' is not defined
